# %%
pred_result = {
    "true_positive": 0,
    "true_negative": 0,
    "false_positive": 0,
    "false_negative": 0,
    "undefined": 0
}

attr_names = [
    "top_left", "top_middle", "top_right",
    "middle_left", "middle_middle", "middle_right",
    "bottom_left", "bottom_middle", "bottom_right"
]

# %%
def name_attrs(instance):
    return set([i + ': ' + str(k) for i, k in zip(attr_names, instance)])

# %%
def write_result(pos_votes, neg_votes, instance):
    if pos_votes > neg_votes:
        if instance[-1] == "positive":
            pred_result["true_positive"] += 1
            return
        else:
            pred_result["false_positive"] += 1
            return
    elif pos_votes < neg_votes:
        if instance[-1] == "negative":
            pred_result["true_negative"] += 1
            return
        else:
            pred_result["false_negative"] += 1
            return
    else:
        pred_result["undefined"] += 1
        return

# %%
def predict(param, train_pos, train_neg, instance, algorithm="First"):
    if algorithm == "First":
        pos_votes, neg_votes = votes_counter_first(param, train_pos, train_neg, instance)
    elif algorithm == "Second":
        pos_votes, neg_votes = votes_counter_second(param, train_pos, train_neg, instance)
    else:
        pos_votes, neg_votes = votes_counter_third(param, train_pos, train_neg, instance)
    pos_votes = pos_votes / float(len(train_pos))
    neg_votes = neg_votes / float(len(train_neg))
    write_result(pos_votes, neg_votes, instance)

# %%
def votes_counter_first(param, train_pos, train_neg, instance):
    named_instance = name_attrs(instance)
    pos_votes = 0
    neg_votes = 0
    for positive in train_pos:
        named_positive = name_attrs(positive)
        if len(named_positive.intersection(named_instance)) / float(len(named_instance)) >= param:
            pos_votes += 1
    for negative in train_neg:
        named_negative = name_attrs(negative)
        if len(named_negative.intersection(named_instance)) / float(len(named_instance)) >= param:
            neg_votes += 1
    return pos_votes, neg_votes

# %%
def votes_counter_second(param, train_pos, train_neg, instance):
    named_instance = name_attrs(instance)
    pos_votes = 0
    neg_votes = 0
    for positive in train_pos:
        named_positive = name_attrs(positive)
        intersec = named_instance.intersection(named_positive)
        includ_counter = 0
        for each in train_neg:
            if intersec.issubset(name_attrs(each)):
                includ_counter += 1
        if includ_counter / float(len(train_neg)) <= param:
            pos_votes += 1

    for negative in train_neg:
        named_negative = name_attrs(negative)
        intersec = named_instance.intersection(named_negative)
        includ_counter = 0
        for each in train_pos:
            if intersec.issubset(name_attrs(each)):
                includ_counter += 1
        if includ_counter / float(len(train_pos)) <= param:
            neg_votes += 1
    return pos_votes, neg_votes

# %%
def votes_counter_third(param, train_pos, train_neg, instance):
    named_instance = name_attrs(instance)
    biggest_positive = [0] * param
    biggest_negative = [0] * param
    for positive in train_pos:
        named_positive = name_attrs(positive)
        smallest_in_list = min(biggest_positive)
        current_intersection = len(named_instance.intersection(named_positive))
        if smallest_in_list < current_intersection:
            biggest_positive.remove(smallest_in_list)
            biggest_positive.append(current_intersection)
    for negative in train_neg:
        named_negative = name_attrs(negative)
        smallest_in_list = min(biggest_negative)
        current_intersection = len(named_instance.intersection(named_negative))
        if smallest_in_list < current_intersection:
            biggest_negative.remove(smallest_in_list)
            biggest_negative.append(current_intersection)
    biggest_negative.sort(reverse=True)
    biggest_positive.sort(reverse=True)

    for neg, pos in zip(biggest_negative, biggest_positive):
        if neg > pos:
            neg_votes = 1
            pos_votes = 0
            return pos_votes, neg_votes
        elif pos > neg:
            pos_votes = 1
            neg_votes = 0
            return pos_votes, neg_votes
    return 0, 0

# %%
def cross_valid_check(param, files_amount=10, blocks_num=10, algorithm="First"):
    accuracy = 0
    for i in range(files_amount):
        split = split_file("train{}.csv".format(i + 1), blocks_num)
        local_accuracy = 0
        for iteration in range(blocks_num):
            train, to_predict = next(split)
            train_pos = [a for a in train if a[-1] == "positive"]
            train_neg = [a for a in train if a[-1] == "negative"]
            for sample in to_predict:
                predict(param, train_pos, train_neg, sample, algorithm)
            local_accuracy += (pred_result["true_positive"] + pred_result["true_negative"]) / len(to_predict)
            print("iteration: {}".format(iteration))
            print(pred_result)
            print("//--------------------------------------")
            for keys in pred_result:
                pred_result[keys] = 0
        local_accuracy = local_accuracy / float(blocks_num)
        accuracy += local_accuracy
    accuracy = accuracy / files_amount
    return accuracy

# %%
def split_file(file_name, blocks_num):
    with open(file_name, "r") as f:
        data = [a.strip().split(",") for a in f][1:]

    for k in range(blocks_num):
        training = [x for i, x in enumerate(data) if i % blocks_num != k]
        validation = [x for i, x in enumerate(data) if i % blocks_num == k]
        yield training, validation

# %%
def cross_valid_executor(files_amount=10, blocks_num=10, algorithm="First"):
    coeff = 0.5
    param = 0.5
    best_accuracy = 0
    for i in range(10):
        if algorithm == "First":
            coeff += 0.05
        elif algorithm == "Second":
            coeff -= 0.05
        else:
            coeff = 5*(i + 1)
        accuracy = cross_valid_check(coeff, files_amount=files_amount, blocks_num=blocks_num, algorithm=algorithm)
        if accuracy > best_accuracy:
            param = coeff
            best_accuracy = accuracy
    return best_accuracy, param

# %%
def my_division(x, y):
    if y == 0:
        return "NaN"
    else:
        return x / float(y)

# %%
def get_result(input_length):
    print(pred_result)
    acc = my_division(pred_result["true_positive"] + pred_result["true_negative"], input_length)
    prec = my_division(pred_result["true_positive"], pred_result["true_positive"] + pred_result["false_positive"])
    FDR = my_division(pred_result["false_positive"], pred_result["false_positive"] + pred_result["true_positive"])
    FPR = my_division(pred_result["false_positive"], pred_result["true_negative"] + pred_result["false_positive"])
    NPV = my_division(pred_result["true_negative"], pred_result["true_negative"] + pred_result["false_negative"])
    TPR = my_division(pred_result["true_positive"], pred_result["true_positive"] + pred_result["false_negative"])
    TNR = my_division(pred_result["true_negative"], pred_result["false_positive"] + pred_result["true_negative"])
    rec = my_division(pred_result["true_positive"], pred_result["true_positive"] + pred_result["false_negative"])
    print("True Positive Rate: {}\nTrue Negative Rate: {}\n\
Negative Predictive Value: {}\nFalse Positive Rate: {}\nFalse Discovery Rate: {}\nAccuracy: {}\n\
Recall: {}\nPrecision: {}".format(TPR, TNR, NPV, FPR, FDR, acc, rec, prec))

# %%
for i in range(10):
    data_name = "train{}.csv".format(i + 1)
    test_name = "test{}.csv".format(i + 1)
    with open(data_name, "r") as f:
        train = [record.strip().split(",") for record in f][1:]
        train_pos = [record for record in train if record[-1] == "positive"]
        train_neg = [record for record in train if record[-1] == "negative"]
    with open(test_name, "r") as f:
        to_predict = [record.strip().split(",") for record in f][1:]
        
    for sample in to_predict:
        predict(0.7, train_pos, train_neg, sample, algorithm="First")

    print("Run number {}".format(i + 1))
    get_result(len(to_predict))
    print("//----------------------------------------------------------------------------------------------------")
    
    for keys in pred_result:
        pred_result[keys] = 0
# Out:
# Run number 1
# {'true_positive': 55, 'true_negative': 32, 'false_positive': 0, 'false_negative': 6, 'undefined': 0}
# True Positive Rate: 0.9016393442622951
# True Negative Rate: 1.0
# Negative Predictive Value: 0.8421052631578947
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 0.9354838709677419
# Recall: 0.9016393442622951
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 2
# {'true_positive': 50, 'true_negative': 36, 'false_positive': 0, 'false_negative': 1, 'undefined': 0}
# True Positive Rate: 0.9803921568627451
# True Negative Rate: 1.0
# Negative Predictive Value: 0.972972972972973
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 0.9885057471264368
# Recall: 0.9803921568627451
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 3
# {'true_positive': 65, 'true_negative': 35, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 4
# {'true_positive': 59, 'true_negative': 30, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 5
# {'true_positive': 58, 'true_negative': 27, 'false_positive': 0, 'false_negative': 4, 'undefined': 0}
# True Positive Rate: 0.9354838709677419
# True Negative Rate: 1.0
# Negative Predictive Value: 0.8709677419354839
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 0.9550561797752809
# Recall: 0.9354838709677419
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 6
# {'true_positive': 56, 'true_negative': 29, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 7
# {'true_positive': 70, 'true_negative': 44, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 8
# {'true_positive': 72, 'true_negative': 34, 'false_positive': 0, 'false_negative': 1, 'undefined': 0}
# True Positive Rate: 0.9863013698630136
# True Negative Rate: 1.0
# Negative Predictive Value: 0.9714285714285714
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 0.9906542056074766
# Recall: 0.9863013698630136
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 9
# {'true_positive': 70, 'true_negative': 33, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 10
# {'true_positive': 58, 'true_negative': 32, 'false_positive': 0, 'false_negative': 1, 'undefined': 0}
# True Positive Rate: 0.9830508474576272
# True Negative Rate: 1.0
# Negative Predictive Value: 0.9696969696969697
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 0.989010989010989
# Recall: 0.9830508474576272
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------

# %%
for i in range(10):
    data_name = "train{}.csv".format(i + 1)
    test_name = "test{}.csv".format(i + 1)
    with open(data_name, "r") as f:
        train = [record.strip().split(",") for record in f][1:]
        train_pos = [record for record in train if record[-1] == "positive"]
        train_neg = [record for record in train if record[-1] == "negative"]
    with open(test_name, "r") as f:
        to_predict = [record.strip().split(",") for record in f][1:]
        
    for sample in to_predict:
        predict(0, train_pos, train_neg, sample, algorithm="Second")
    
    print("Run number {}".format(i + 1))
    get_result(len(to_predict))
    print("//----------------------------------------------------------------------------------------------------")
    
    for keys in pred_result:
        pred_result[keys] = 0
# Out:
# Run number 1
# {'true_positive': 61, 'true_negative': 32, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 2
# {'true_positive': 51, 'true_negative': 34, 'false_positive': 2, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9444444444444444
# Negative Predictive Value: 1.0
# False Positive Rate: 0.05555555555555555
# False Discovery Rate: 0.03773584905660377
# AccuracyPrecision: 0.9770114942528736
# Recall: 1.0
# Precision: 0.9622641509433962
# //----------------------------------------------------------------------------------------------------
# Run number 3
# {'true_positive': 65, 'true_negative': 35, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 4
# {'true_positive': 59, 'true_negative': 28, 'false_positive': 2, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9333333333333333
# Negative Predictive Value: 1.0
# False Positive Rate: 0.06666666666666667
# False Discovery Rate: 0.03278688524590164
# AccuracyPrecision: 0.9775280898876404
# Recall: 1.0
# Precision: 0.9672131147540983
# //----------------------------------------------------------------------------------------------------
# Run number 5
# {'true_positive': 62, 'true_negative': 25, 'false_positive': 2, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9259259259259259
# Negative Predictive Value: 1.0
# False Positive Rate: 0.07407407407407407
# False Discovery Rate: 0.03125
# AccuracyPrecision: 0.9775280898876404
# Recall: 1.0
# Precision: 0.96875
# //----------------------------------------------------------------------------------------------------
# Run number 6
# {'true_positive': 56, 'true_negative': 29, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 7
# {'true_positive': 70, 'true_negative': 43, 'false_positive': 1, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9772727272727273
# Negative Predictive Value: 1.0
# False Positive Rate: 0.022727272727272728
# False Discovery Rate: 0.014084507042253521
# AccuracyPrecision: 0.9912280701754386
# Recall: 1.0
# Precision: 0.9859154929577465
# //----------------------------------------------------------------------------------------------------
# Run number 8
# {'true_positive': 73, 'true_negative': 33, 'false_positive': 1, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9705882352941176
# Negative Predictive Value: 1.0
# False Positive Rate: 0.029411764705882353
# False Discovery Rate: 0.013513513513513514
# AccuracyPrecision: 0.9906542056074766
# Recall: 1.0
# Precision: 0.9864864864864865
# //----------------------------------------------------------------------------------------------------
# Run number 9
# {'true_positive': 70, 'true_negative': 32, 'false_positive': 1, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9696969696969697
# Negative Predictive Value: 1.0
# False Positive Rate: 0.030303030303030304
# False Discovery Rate: 0.014084507042253521
# AccuracyPrecision: 0.9902912621359223
# Recall: 1.0
# Precision: 0.9859154929577465
# //----------------------------------------------------------------------------------------------------
# Run number 10
# {'true_positive': 59, 'true_negative': 32, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------

# %%
for i in range(10):
    data_name = "train{}.csv".format(i + 1)
    test_name = "test{}.csv".format(i + 1)
    with open(data_name, "r") as f:
        train = [record.strip().split(",") for record in f][1:]
        train_pos = [record for record in train if record[-1] == "positive"]
        train_neg = [record for record in train if record[-1] == "negative"]
    with open(test_name, "r") as f:
        to_predict = [record.strip().split(",") for record in f][1:]
        
    for sample in to_predict:
        predict(25, train_pos, train_neg, sample, algorithm="Third")
    
    print("Run number {}".format(i + 1))
    get_result(len(to_predict))
    print("//----------------------------------------------------------------------------------------------------")
    
    for keys in pred_result:
        pred_result[keys] = 0
# Out:
# Run number 1
# {'true_positive': 61, 'true_negative': 32, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 2
# {'true_positive': 51, 'true_negative': 34, 'false_positive': 2, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9444444444444444
# Negative Predictive Value: 1.0
# False Positive Rate: 0.05555555555555555
# False Discovery Rate: 0.03773584905660377
# AccuracyPrecision: 0.9770114942528736
# Recall: 1.0
# Precision: 0.9622641509433962
# //----------------------------------------------------------------------------------------------------
# Run number 3
# {'true_positive': 65, 'true_negative': 33, 'false_positive': 2, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9428571428571428
# Negative Predictive Value: 1.0
# False Positive Rate: 0.05714285714285714
# False Discovery Rate: 0.029850746268656716
# AccuracyPrecision: 0.98
# Recall: 1.0
# Precision: 0.9701492537313433
# //----------------------------------------------------------------------------------------------------
# Run number 4
# {'true_positive': 59, 'true_negative': 28, 'false_positive': 2, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9333333333333333
# Negative Predictive Value: 1.0
# False Positive Rate: 0.06666666666666667
# False Discovery Rate: 0.03278688524590164
# AccuracyPrecision: 0.9775280898876404
# Recall: 1.0
# Precision: 0.9672131147540983
# //----------------------------------------------------------------------------------------------------
# Run number 5
# {'true_positive': 62, 'true_negative': 26, 'false_positive': 1, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9629629629629629
# Negative Predictive Value: 1.0
# False Positive Rate: 0.037037037037037035
# False Discovery Rate: 0.015873015873015872
# AccuracyPrecision: 0.9887640449438202
# Recall: 1.0
# Precision: 0.9841269841269841
# //----------------------------------------------------------------------------------------------------
# Run number 6
# {'true_positive': 56, 'true_negative': 29, 'false_positive': 0, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 1.0
# Negative Predictive Value: 1.0
# False Positive Rate: 0.0
# False Discovery Rate: 0.0
# AccuracyPrecision: 1.0
# Recall: 1.0
# Precision: 1.0
# //----------------------------------------------------------------------------------------------------
# Run number 7
# {'true_positive': 70, 'true_negative': 41, 'false_positive': 3, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9318181818181818
# Negative Predictive Value: 1.0
# False Positive Rate: 0.06818181818181818
# False Discovery Rate: 0.0410958904109589
# AccuracyPrecision: 0.9736842105263158
# Recall: 1.0
# Precision: 0.958904109589041
# //----------------------------------------------------------------------------------------------------
# Run number 8
# {'true_positive': 73, 'true_negative': 33, 'false_positive': 1, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9705882352941176
# Negative Predictive Value: 1.0
# False Positive Rate: 0.029411764705882353
# False Discovery Rate: 0.013513513513513514
# AccuracyPrecision: 0.9906542056074766
# Recall: 1.0
# Precision: 0.9864864864864865
# //----------------------------------------------------------------------------------------------------
# Run number 9
# {'true_positive': 70, 'true_negative': 32, 'false_positive': 1, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.9696969696969697
# Negative Predictive Value: 1.0
# False Positive Rate: 0.030303030303030304
# False Discovery Rate: 0.014084507042253521
# AccuracyPrecision: 0.9902912621359223
# Recall: 1.0
# Precision: 0.9859154929577465
# //----------------------------------------------------------------------------------------------------
# Run number 10
# {'true_positive': 59, 'true_negative': 31, 'false_positive': 1, 'false_negative': 0, 'undefined': 0}
# True Positive Rate: 1.0
# True Negative Rate: 0.96875
# Negative Predictive Value: 1.0
# False Positive Rate: 0.03125
# False Discovery Rate: 0.016666666666666666
# AccuracyPrecision: 0.989010989010989
# Recall: 1.0
# Precision: 0.9833333333333333
# //----------------------------------------------------------------------------------------------------

# %%
best_accuracy, best_param = cross_valid_executor(files_amount=10, blocks_num=3, algorithm="Third")
print("best_accuracy: ", best_accuracy)
print("parameter: ", best_param)
# Out:
# iteration: 0
# {'true_positive': 176, 'true_negative': 71, 'false_positive': 2, 'false_negative': 0, 'undefined': 40}
# //--------------------------------------
# iteration: 1
# {'true_positive': 179, 'true_negative': 79, 'false_positive': 0, 'false_negative': 0, 'undefined': 30}
# //--------------------------------------
# iteration: 2
# {'true_positive': 175, 'true_negative': 76, 'false_positive': 2, 'false_negative': 0, 'undefined': 35}
# //--------------------------------------
# iteration: 0
# {'true_positive': 182, 'true_negative': 68, 'false_positive': 3, 'false_negative': 0, 'undefined': 38}
# //--------------------------------------
# iteration: 1
# {'true_positive': 181, 'true_negative': 69, 'false_positive': 3, 'false_negative': 0, 'undefined': 37}
# //--------------------------------------
# iteration: 2
# {'true_positive': 184, 'true_negative': 76, 'false_positive': 0, 'false_negative': 0, 'undefined': 30}
# //--------------------------------------
# iteration: 0
# {'true_positive': 175, 'true_negative': 70, 'false_positive': 3, 'false_negative': 0, 'undefined': 38}
# //--------------------------------------
# iteration: 1
# {'true_positive': 179, 'true_negative': 72, 'false_positive': 1, 'false_negative': 0, 'undefined': 34}
# //--------------------------------------
# iteration: 2
# {'true_positive': 175, 'true_negative': 74, 'false_positive': 2, 'false_negative': 0, 'undefined': 35}
# //--------------------------------------
# iteration: 0
# {'true_positive': 179, 'true_negative': 68, 'false_positive': 1, 'false_negative': 0, 'undefined': 42}
# //--------------------------------------
# iteration: 1
# {'true_positive': 171, 'true_negative': 76, 'false_positive': 0, 'false_negative': 0, 'undefined': 43}
# //--------------------------------------
# iteration: 2
# {'true_positive': 176, 'true_negative': 73, 'false_positive': 0, 'false_negative': 0, 'undefined': 40}
# //--------------------------------------
# iteration: 0
# {'true_positive': 179, 'true_negative': 68, 'false_positive': 4, 'false_negative': 0, 'undefined': 39}
# //--------------------------------------
# iteration: 1
# {'true_positive': 179, 'true_negative': 76, 'false_positive': 3, 'false_negative': 0, 'undefined': 32}
# //--------------------------------------
# iteration: 2
# {'true_positive': 174, 'true_negative': 80, 'false_positive': 0, 'false_negative': 0, 'undefined': 35}
# //--------------------------------------
# iteration: 0
# {'true_positive': 177, 'true_negative': 70, 'false_positive': 1, 'false_negative': 0, 'undefined': 43}
# //--------------------------------------
# iteration: 1
# {'true_positive': 178, 'true_negative': 70, 'false_positive': 2, 'false_negative': 0, 'undefined': 41}
# //--------------------------------------
# iteration: 2
# {'true_positive': 176, 'true_negative': 71, 'false_positive': 1, 'false_negative': 0, 'undefined': 43}
# //--------------------------------------
# iteration: 0
# {'true_positive': 175, 'true_negative': 66, 'false_positive': 1, 'false_negative': 1, 'undefined': 39}
# //--------------------------------------
# iteration: 1
# {'true_positive': 174, 'true_negative': 67, 'false_positive': 1, 'false_negative': 0, 'undefined': 39}
# //--------------------------------------
# iteration: 2
# {'true_positive': 176, 'true_negative': 62, 'false_positive': 2, 'false_negative': 0, 'undefined': 41}
# //--------------------------------------
# iteration: 0
# {'true_positive': 175, 'true_negative': 70, 'false_positive': 2, 'false_negative': 0, 'undefined': 37}
# //--------------------------------------
# iteration: 1
# {'true_positive': 164, 'true_negative': 74, 'false_positive': 0, 'false_negative': 0, 'undefined': 46}
# //--------------------------------------
# iteration: 2
# {'true_positive': 173, 'true_negative': 65, 'false_positive': 2, 'false_negative': 0, 'undefined': 43}
# //--------------------------------------
# iteration: 0
# {'true_positive': 176, 'true_negative': 72, 'false_positive': 0, 'false_negative': 0, 'undefined': 37}
# //--------------------------------------
# iteration: 1
# {'true_positive': 171, 'true_negative': 71, 'false_positive': 1, 'false_negative': 0, 'undefined': 42}
# //--------------------------------------
# iteration: 2
# {'true_positive': 176, 'true_negative': 66, 'false_positive': 1, 'false_negative': 0, 'undefined': 42}
# //--------------------------------------
# iteration: 0
# {'true_positive': 175, 'true_negative': 71, 'false_positive': 1, 'false_negative': 0, 'undefined': 42}
# //--------------------------------------
# iteration: 1
# {'true_positive': 174, 'true_negative': 69, 'false_positive': 0, 'false_negative': 0, 'undefined': 46}
# //--------------------------------------
# iteration: 2
# {'true_positive': 170, 'true_negative': 64, 'false_positive': 2, 'false_negative': 0, 'undefined': 53}
# //--------------------------------------
# iteration: 0
# {'true_positive': 187, 'true_negative': 93, 'false_positive': 6, 'false_negative': 1, 'undefined': 2}
# //--------------------------------------
# iteration: 1
# {'true_positive': 187, 'true_negative': 97, 'false_positive': 2, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 2
# {'true_positive': 187, 'true_negative': 95, 'false_positive': 4, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 0
# {'true_positive': 191, 'true_negative': 92, 'false_positive': 5, 'false_negative': 0, 'undefined': 3}
# //--------------------------------------
# iteration: 1
# {'true_positive': 192, 'true_negative': 92, 'false_positive': 4, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 2
# {'true_positive': 190, 'true_negative': 96, 'false_positive': 0, 'false_negative': 0, 'undefined': 4}
# //--------------------------------------
# iteration: 0
# {'true_positive': 186, 'true_negative': 90, 'false_positive': 5, 'false_negative': 0, 'undefined': 5}
# //--------------------------------------
# iteration: 1
# {'true_positive': 187, 'true_negative': 94, 'false_positive': 2, 'false_negative': 0, 'undefined': 3}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 90, 'false_positive': 6, 'false_negative': 1, 'undefined': 4}
# //--------------------------------------
# iteration: 0
# {'true_positive': 188, 'true_negative': 93, 'false_positive': 5, 'false_negative': 0, 'undefined': 4}
# //--------------------------------------
# iteration: 1
# {'true_positive': 189, 'true_negative': 96, 'false_positive': 3, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 2
# {'true_positive': 189, 'true_negative': 97, 'false_positive': 2, 'false_negative': 0, 'undefined': 1}
# //--------------------------------------
# iteration: 0
# {'true_positive': 188, 'true_negative': 90, 'false_positive': 5, 'false_negative': 0, 'undefined': 7}
# //--------------------------------------
# iteration: 1
# {'true_positive': 188, 'true_negative': 96, 'false_positive': 5, 'false_negative': 0, 'undefined': 1}
# //--------------------------------------
# iteration: 2
# {'true_positive': 188, 'true_negative': 98, 'false_positive': 2, 'false_negative': 0, 'undefined': 1}
# //--------------------------------------
# iteration: 0
# {'true_positive': 190, 'true_negative': 96, 'false_positive': 3, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 1
# {'true_positive': 190, 'true_negative': 92, 'false_positive': 7, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 2
# {'true_positive': 189, 'true_negative': 92, 'false_positive': 7, 'false_negative': 1, 'undefined': 2}
# //--------------------------------------
# iteration: 0
# {'true_positive': 184, 'true_negative': 86, 'false_positive': 4, 'false_negative': 1, 'undefined': 7}
# //--------------------------------------
# iteration: 1
# {'true_positive': 183, 'true_negative': 89, 'false_positive': 3, 'false_negative': 0, 'undefined': 6}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 90, 'false_positive': 4, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 0
# {'true_positive': 185, 'true_negative': 93, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 184, 'true_negative': 94, 'false_positive': 3, 'false_negative': 0, 'undefined': 3}
# //--------------------------------------
# iteration: 2
# {'true_positive': 184, 'true_negative': 88, 'false_positive': 9, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 0
# {'true_positive': 186, 'true_negative': 93, 'false_positive': 5, 'false_negative': 0, 'undefined': 1}
# //--------------------------------------
# iteration: 1
# {'true_positive': 184, 'true_negative': 94, 'false_positive': 2, 'false_negative': 1, 'undefined': 4}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 94, 'false_positive': 4, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 0
# {'true_positive': 189, 'true_negative': 94, 'false_positive': 4, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 1
# {'true_positive': 189, 'true_negative': 95, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 186, 'true_negative': 92, 'false_positive': 6, 'false_negative': 0, 'undefined': 5}
# //--------------------------------------
# iteration: 0
# {'true_positive': 187, 'true_negative': 93, 'false_positive': 7, 'false_negative': 1, 'undefined': 1}
# //--------------------------------------
# iteration: 1
# {'true_positive': 187, 'true_negative': 97, 'false_positive': 3, 'false_negative': 0, 'undefined': 1}
# //--------------------------------------
# iteration: 2
# {'true_positive': 187, 'true_negative': 95, 'false_positive': 4, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 0
# {'true_positive': 191, 'true_negative': 93, 'false_positive': 5, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 1
# {'true_positive': 192, 'true_negative': 92, 'false_positive': 4, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 2
# {'true_positive': 190, 'true_negative': 96, 'false_positive': 0, 'false_negative': 0, 'undefined': 4}
# //--------------------------------------
# iteration: 0
# {'true_positive': 186, 'true_negative': 90, 'false_positive': 9, 'false_negative': 0, 'undefined': 1}
# //--------------------------------------
# iteration: 1
# {'true_positive': 187, 'true_negative': 94, 'false_positive': 4, 'false_negative': 0, 'undefined': 1}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 90, 'false_positive':
 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 188, 'true_negative': 99, 'false_positive': 2, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 190, 'true_negative': 96, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 190, 'true_negative': 92, 'false_positive': 9, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 189, 'true_negative': 92, 'false_positive': 9, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 185, 'true_negative': 88, 'false_positive': 8, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 184, 'true_negative': 89, 'false_positive': 7, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 90, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 185, 'true_negative': 93, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 184, 'true_negative': 94, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 184, 'true_negative': 89, 'false_positive': 10, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 186, 'true_negative': 93, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 184, 'true_negative': 95, 'false_positive': 5, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 94, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 189, 'true_negative': 95, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 189, 'true_negative': 95, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 186, 'true_negative': 92, 'false_positive': 8, 'false_negative': 3, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 187, 'true_negative': 93, 'false_positive': 7, 'false_negative': 2, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 188, 'true_negative': 97, 'false_positive': 3, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 187, 'true_negative': 95, 'false_positive': 5, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 191, 'true_negative': 93, 'false_positive': 6, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 192, 'true_negative': 93, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 190, 'true_negative': 97, 'false_positive': 2, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 186, 'true_negative': 90, 'false_positive': 9, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 187, 'true_negative': 94, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 90, 'false_positive': 9, 'false_negative': 2, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 189, 'true_negative': 93, 'false_positive': 8, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 189, 'true_negative': 96, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 189, 'true_negative': 97, 'false_positive': 3, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 188, 'true_negative': 91, 'false_positive': 9, 'false_negative': 0, 'undefined': 2}
# //--------------------------------------
# iteration: 1
# {'true_positive': 188, 'true_negative': 96, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 188, 'true_negative': 99, 'false_positive': 2, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 190, 'true_negative': 96, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 190, 'true_negative': 92, 'false_positive': 9, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 189, 'true_negative': 92, 'false_positive': 9, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 185, 'true_negative': 88, 'false_positive': 8, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 184, 'true_negative': 89, 'false_positive': 7, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 90, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 185, 'true_negative': 93, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 184, 'true_negative': 94, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 184, 'true_negative': 89, 'false_positive': 10, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 186, 'true_negative': 93, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 184, 'true_negative': 95, 'false_positive': 5, 'false_negative': 1, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 94, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 189, 'true_negative': 95, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 189, 'true_negative': 95, 'false_positive': 5, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 186, 'true_negative': 92, 'false_positive': 8, 'false_negative': 3, 'undefined': 0}
# //--------------------------------------
# best_accuracy:  0.9765561962563604
# parameter:  25

# %%
best_accuracy, best_param = cross_valid_executor(files_amount=10, blocks_num=3, algorithm="Second")
print("best_accuracy: ", best_accuracy)
print("parameter: ", best_param)
# Out:
# iteration: 0
# {'true_positive': 131, 'true_negative': 64, 'false_positive': 36, 'false_negative': 58, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 146, 'true_negative': 65, 'false_positive': 34, 'false_negative': 42, 'undefined': 1}
# //--------------------------------------
# iteration: 2
# {'true_positive': 136, 'true_negative': 65, 'false_positive': 35, 'false_negative': 52, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 137, 'true_negative': 68, 'false_positive': 31, 'false_negative': 55, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 138, 'true_negative': 66, 'false_positive': 32, 'false_negative': 54, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 150, 'true_negative': 67, 'false_positive': 30, 'false_negative': 41, 'undefined': 2}
# //--------------------------------------
# iteration: 0
# {'true_positive': 131, 'true_negative': 64, 'false_positive': 32, 'false_negative': 55, 'undefined': 4}
# //--------------------------------------
# iteration: 1
# {'true_positive': 144, 'true_negative': 58, 'false_positive': 40, 'false_negative': 43, 'undefined': 1}
# //--------------------------------------
# iteration: 2
# {'true_positive': 136, 'true_negative': 64, 'false_positive': 35, 'false_negative': 51, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 131, 'true_negative': 67, 'false_positive': 34, 'false_negative': 58, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 150, 'true_negative': 65, 'false_positive': 36, 'false_negative': 39, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 128, 'true_negative': 65, 'false_positive': 35, 'false_negative': 61, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 122, 'true_negative': 71, 'false_positive': 31, 'false_negative': 66, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 131, 'true_negative': 70, 'false_positive': 32, 'false_negative': 57, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 122, 'true_negative': 67, 'false_positive': 34, 'false_negative': 66, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 119, 'true_negative': 75, 'false_positive': 26, 'false_negative': 71, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 134, 'true_negative': 76, 'false_positive': 25, 'false_negative': 56, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 132, 'true_negative': 68, 'false_positive': 33, 'false_negative': 58, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive':
 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 189, 'true_negative': 94, 'false_positive': 6, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 189, 'true_negative': 91, 'false_positive': 9, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 189, 'true_negative': 87, 'false_positive': 13, 'false_negative': 0, 'undefined': 0}
# //--------------------------------------
# best_accuracy:  0.972044179728862
# parameter:  6.938893903907228e-17

# %%
best_accuracy, best_param = cross_valid_executor(files_amount=10, blocks_num=3, algorithm="First")
print("best_accuracy: ", best_accuracy)
print("parameter: ", best_param)
# Out:
# iteration: 0
# {'true_positive': 140, 'true_negative': 67, 'false_positive': 33, 'false_negative': 49, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 151, 'true_negative': 78, 'false_positive': 22, 'false_negative': 37, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 135, 'true_negative': 72, 'false_positive': 28, 'false_negative': 53, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 143, 'true_negative': 68, 'false_positive': 31, 'false_negative': 49, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 143, 'true_negative': 74, 'false_positive': 24, 'false_negative': 49, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 136, 'true_negative': 81, 'false_positive': 18, 'false_negative': 55, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 133, 'true_negative': 70, 'false_positive': 29, 'false_negative': 54, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 139, 'true_negative': 78, 'false_positive': 20, 'false_negative': 47, 'undefined': 2}
# //--------------------------------------
# iteration: 2
# {'true_positive': 137, 'true_negative': 73, 'false_positive': 26, 'false_negative': 48, 'undefined': 2}
# //--------------------------------------
# iteration: 0
# {'true_positive': 144, 'true_negative': 75, 'false_positive': 26, 'false_negative': 45, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 145, 'true_negative': 75, 'false_positive': 26, 'false_negative': 44, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 138, 'true_negative': 78, 'false_positive': 22, 'false_negative': 51, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 142, 'true_negative': 73, 'false_positive': 29, 'false_negative': 46, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 139, 'true_negative': 80, 'false_positive': 22, 'false_negative': 49, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 141, 'true_negative': 77, 'false_positive': 24, 'false_negative': 47, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 141, 'true_negative': 80, 'false_positive': 21, 'false_negative': 49, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 143, 'true_negative': 75, 'false_positive': 26, 'false_negative': 47, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 132, 'true_negative': 70, 'false_positive': 31, 'false_negative': 58, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 139, 'true_negative': 71, 'false_positive': 25, 'false_negative': 47, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 142, 'true_negative': 71, 'false_positive': 25, 'false_negative': 43, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 131, 'true_negative': 71, 'false_positive': 25, 'false_negative': 54, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 135, 'true_negative': 69, 'false_positive': 30, 'false_negative': 50, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 133, 'true_negative': 80, 'false_positive': 20, 'false_negative': 51, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 132, 'true_negative': 73, 'false_positive': 26, 'false_negative': 52, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 135, 'true_negative': 74, 'false_positive': 25, 'false_negative': 51, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 136, 'true_negative': 78, 'false_positive': 22, 'false_negative': 49, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 132, 'true_negative': 74, 'false_positive': 26, 'false_negative': 53, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 135, 'true_negative': 78, 'false_positive': 22, 'false_negative': 54, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 142, 'true_negative': 72, 'false_positive': 28, 'false_negative': 47, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 136, 'true_negative': 71, 'false_positive': 29, 'false_negative': 53, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 157, 'true_negative': 86, 'false_positive': 14, 'false_negative': 32, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 162, 'true_negative': 86, 'false_positive': 14, 'false_negative': 26, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 151, 'true_negative': 96, 'false_positive': 4, 'false_negative': 37, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 150, 'true_negative': 84, 'false_positive': 15, 'false_negative': 42, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 158, 'true_negative': 86, 'false_positive': 12, 'false_negative': 34, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 149, 'true_negative': 95, 'false_positive': 4, 'false_negative': 42, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 151, 'true_negative': 81, 'false_positive': 17, 'false_negative': 36, 'undefined': 1}
# //--------------------------------------
# iteration: 1
# {'true_positive': 155, 'true_negative': 90, 'false_positive': 9, 'false_negative': 32, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 154, 'true_negative': 90, 'false_positive': 8, 'false_negative': 33, 'undefined': 1}
# //--------------------------------------
# iteration: 0
# {'true_positive': 151, 'true_negative': 88, 'false_positive': 13, 'false_negative': 38, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 150, 'true_negative': 91, 'false_positive': 10, 'false_negative': 39, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 154, 'true_negative': 89, 'false_positive': 11, 'false_negative': 35, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 155, 'true_negative': 88, 'false_positive': 14, 'false_negative': 33, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 152, 'true_negative': 90, 'false_positive': 12, 'false_negative': 36, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 147, 'true_negative': 92, 'false_positive': 9, 'false_negative': 41, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 155, 'true_negative': 90, 'false_positive': 11, 'false_negative': 35, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 155, 'true_negative': 84, 'false_positive': 17, 'false_negative': 35, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 147, 'true_negative': 89, 'false_positive': 12, 'false_negative': 43, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 153, 'true_negative': 86, 'false_positive': 10, 'false_negative': 33, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 149, 'true_negative': 81, 'false_positive': 15, 'false_negative': 36, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 133, 'true_negative': 90, 'false_positive': 6, 'false_negative': 52, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 139, 'true_negative': 81, 'false_positive': 18, 'false_negative': 46, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 146, 'true_negative': 90, 'false_positive': 10, 'false_negative': 38, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 155, 'true_negative': 86, 'false_positive': 13, 'false_negative': 29, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 150, 'true_negative': 90, 'false_positive': 9, 'false_negative': 36, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 148, 'true_negative': 89, 'false_positive': 11, 'false_negative': 37, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 144, 'true_negative': 91, 'false_positive': 9, 'false_negative': 41, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 154, 'true_negative': 90, 'false_positive': 10, 'false_negative': 35, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 148, 'true_negative': 91, 'false_positive': 9, 'false_negative': 41, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 146, 'true_negative': 87, 'false_positive': 13, 'false_negative': 43, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 157, 'true_negative': 86, 'false_positive': 14, 'false_negative': 32, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 162, 'true_negative': 86, 'false_positive': 14, 'false_negative': 26, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 151, 'true_negative': 96, 'false_positive': 4, 'false_negative': 37, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 150, 'true_negative': 84, 'false_positive': 15, 'false_negative': 42, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 158, 'true_negative': 86, 'false_positive': 12, 'false_negative': 34, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 149, 'true_negative': 95, 'false_positive': 4, 'false_negative': 42, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 151, 'true_negative': 81, 'false_positive': 17, 'false_negative': 36, 'undefined': 1}
# //--------------------------------------
# iteration: 1
# {'true_positive': 155, 'true_negative': 90, 'false_positive': 9, 'false_negative': 32, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 154, 'true_negative': 90, 'false_positive': 8, 'false_negative': 33, 'undefined': 1}
# //--------------------------------------
# iteration: 0
# {'true_positive': 151, 'true_negative': 88, 'false_positive': 13, 'false_negative': 38, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 150, 'true_negative': 91, 'false_positive': 10, 'false_negative': 39, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 154, 'true_negative': 89, 'false_positive': 11, 'false_negative': 35, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 155, 'true_negative': 88, 'false_positive': 14, 'false_negative': 33, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 152, 'true_negative': 90, 'false_positive': 12, 'false_negative': 36, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 147, 'true_negative': 92, 'false_positive': 9, 'false_negative': 41, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 155, 'true_negative': 90, 'false_positive': 11, 'false_negative': 35, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 155, 'true_negative': 84, 'false_positive': 17, 'false_negative': 35, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 147, 'true_negative': 89, 'false_positive': 12, 'false_negative': 43, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 153, 'true_negative': 86, 'false_positive': 10, 'false_negative': 33, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 149, 'true_negative': 81, 'false_positive': 15, 'false_negative': 36, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive':
 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 183, 'true_negative': 98, 'false_positive': 1, 'false_negative': 4, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 182, 'true_negative': 100, 'false_positive': 1, 'false_negative': 7, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 182, 'true_negative': 101, 'false_positive': 0, 'false_negative': 7, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 100, 'false_positive': 0, 'false_negative': 4, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 183, 'true_negative': 101, 'false_positive': 1, 'false_negative': 5, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 185, 'true_negative': 101, 'false_positive': 1, 'false_negative': 3, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 183, 'true_negative': 101, 'false_positive': 0, 'false_negative': 5, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 185, 'true_negative': 101, 'false_positive': 0, 'false_negative': 5, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 184, 'true_negative': 100, 'false_positive': 1, 'false_negative': 6, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 185, 'true_negative': 100, 'false_positive': 1, 'false_negative': 5, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 179, 'true_negative': 96, 'false_positive': 0, 'false_negative': 7, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 178, 'true_negative': 96, 'false_positive': 0, 'false_negative': 7, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 180, 'true_negative': 96, 'false_positive': 0, 'false_negative': 5, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 178, 'true_negative': 99, 'false_positive': 0, 'false_negative': 7, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 176, 'true_negative': 100, 'false_positive': 0, 'false_negative': 8, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 178, 'true_negative': 99, 'false_positive': 0, 'false_negative': 6, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 181, 'true_negative': 99, 'false_positive': 0, 'false_negative': 5, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 176, 'true_negative': 100, 'false_positive': 0, 'false_negative': 9, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 181, 'true_negative': 100, 'false_positive': 0, 'false_negative': 4, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 185, 'true_negative': 100, 'false_positive': 0, 'false_negative': 4, 'undefined': 0}
# //--------------------------------------
# iteration: 1
# {'true_positive': 181, 'true_negative': 100, 'false_positive': 0, 'false_negative': 8, 'undefined': 0}
# //--------------------------------------
# iteration: 2
# {'true_positive': 178, 'true_negative': 99, 'false_positive': 1, 'false_negative': 11, 'undefined': 0}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 282}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 283}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 282}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 283}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 282}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 283}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 282}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 283}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 288}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 286}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 290}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 291}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 282}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 281}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 284}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 283}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 285}
# //--------------------------------------
# iteration: 0
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 1
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# iteration: 2
# {'true_positive': 0, 'true_negative': 0, 'false_positive': 0, 'false_negative': 0, 'undefined': 289}
# //--------------------------------------
# best_accuracy:  0.9784285926194078
# parameter:  0.7000000000000002

# %%
while 1: 
    data_name = input('Enter train_data file_name (or "Exit" if you\'re done): ')
    if data_name == "Exit":
        break
    test_name = input('Enter test_data file_name (or "Exit" if you\'re done): ')
    if test_name == "Exit":
        break

    with open(data_name, "r") as f:
        train = [record.strip().split(",") for record in f][1:]
        train_pos = [record for record in train if record[-1] == "positive"]
        train_neg = [record for record in train if record[-1] == "negative"]
    with open(test_name, "r") as f:
        to_predict = [record.strip().split(",") for record in f][1:]
        
    for sample in to_predict:
        predict(0.7, train_pos, train_neg, sample, algorithm="First")
    
    get_result(len(to_predict))
    
    for keys in pred_result:
        pred_result[keys] = 0
# Out:
# Enter train_data file_name (or "Exit" if you're done): Exit
